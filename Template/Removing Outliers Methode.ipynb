# %% [markdown]
# # Menentukan Outliers

# %%
# Untuk melihat Upper limit dan Lower limit dari setiap kolom, kita bisa menggunakan rumus berikut:

#u_limit_med = data['MedInc'].mean() + 3 * data['MedInc'].std()
#l_limit_med = data['MedInc'].mean() - 3 * data['MedInc'].std()
#----------------------------------------------------------------------
#u_limit_rom = data['AveRooms'].mean() + 3 * data['AveRooms'].std()
#l_limit_rom = data['AveRooms'].mean() - 3 * data['AveRooms'].std()
#----------------------------------------------------------------------
#u_limit_bed = data['AveBedrms'].mean() + 3 * data['AveBedrms'].std()
#l_limit_bed = data['AveBedrms'].mean() - 3 * data['AveBedrms'].std()
#----------------------------------------------------------------------
#u_limit_pop = data['Population'].mean() + 3 * data['Population'].std()
#l_limit_pop = data['Population'].mean() - 3 * data['Population'].std()
#----------------------------------------------------------------------
#u_limit_occ = data['AveOccup'].mean() + 3 * data['AveOccup'].std()
#l_limit_occ = data['AveOccup'].mean() - 3 * data['AveOccup'].std()

#print('upper limit medinc :', u_limit_med)
#print('lower limit medinc :', l_limit_med)
#print(50*'-')
#print('upper limit averooms :', u_limit_rom)
#print('lower limit averooms :', l_limit_rom)
#print(50*'-')
#print('upper limit avebedrms :', u_limit_bed)
#print('lower limit avebedrms :', l_limit_bed)
#print(50*'-')
#print('upper limit population :', u_limit_pop)
#print('lower limit population :', l_limit_pop)
#print(50*'-')
#print('upper limit aveoccup :', u_limit_occ)
#print('lower limit aveoccup :', l_limit_occ)

# %% [markdown]
# # **Z-Score Methode**

# %%
# Menemukan Outlier
#data.loc[(data["MedInc"] > u_limit_med) | (data['MedInc'] < l_limit_med)]

# %%
#new_df_med = data.loc[(data["MedInc"] < u_limit_med) & (data['MedInc'] > l_limit_med)]
#print('Trimming - Removing Outliers From Data:')
#print(50*'=')
#print('Before Removing Outliers :', len(data))
#print('After Removing Outliers :', len(new_df_med))
#print('Jumlah Outliers :', len(data) - len(new_df_med))
#print(50*'=')

# %%
#sns.boxplot(new_df_med['MedInc'])

# %%
# Capping - change the outlier values to upper (or) lower limit values
#new_df_med = data.copy()
#new_df_med.loc[new_df_med['MedInc'] > u_limit_med, 'MedInc'] = u_limit_med
#new_df_med.loc[new_df_med['MedInc'] < l_limit_med, 'MedInc'] = l_limit_med
#print('Capping - Removing Outliers From Data:')
#print(50*'=')
#print('Before Removing Outliers :', len(data))
#print('After Removing Outliers :', len(new_df_med))
#print('Jumlah Outliers :', len(data) - len(new_df_med))
#print(50*'=')
#sns.boxplot(new_df_med['MedInc'])

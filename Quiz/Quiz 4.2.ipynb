# %% [markdown]
# # Quiz 4.2
#
# 1. Buat file .ipynb (Jupyter Notebook).
# 2. Cari Data Apapun (Tulis deskripsi data “tentang apa” di markdown .ipynb)
# 3. Import Data tersebut ke file .ipynb (Minimal 5 Variabel Numerik dan Minimal 100 Values)
# 4. Preview Datanya
# 5. Lakukan Seleksi/filter Variabel hanya yang numerik (Cek di ppt pertemuan ke 3)
# 6. Lakukan Visualisasi Heatmap dan Pairplot
# 7. Simpan file .ipynb
# 8. Upload ke Github file .ipynb dan file data nya

# %%
#Import Modul

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## Import Dataset
#
# Sumber dataset : [Kaggle](https://www.kaggle.com/datasets/lucalullo/global-suicide-rates-by-country-2000-2021)
#
# This dataset contains suicide mortality rates per 100,000 population for countries around the world between 2000 and 2021.
#
# The dataset includes demographic breakdowns by sex and age group and allows analysis of global suicide trends, gender differences in suicide mortality, and age-related risk patterns.
#
# The dataset covers approximately 185 countries and territories worldwide.

# %%
#import data sets

data = pd.read_csv(r"C:\Users\Mareko\OneDrive\Documents\Python Statistika\DataSets\tassi-di-suicidio-globali-per-paese-2000-2021.csv", sep=",")
df = pd.DataFrame(data)
df = df.head(101)
print(df)
# Out:
#     iso_code      country  year     sex age_group  suicide_rate
# 0        AFG  Afghanistan  2000    male       ALL      5.793457
# 1        AFG  Afghanistan  2000    both       ALL      4.356148
# 2        AFG  Afghanistan  2000  female       ALL      2.910393
# 3        AFG  Afghanistan  2001    male       ALL      5.831328
# 4        AFG  Afghanistan  2001    both       ALL      4.383031
# ..       ...          ...   ...     ...       ...           ...
# 96       AFG  Afghanistan  2021    both     50_59      7.813925
# 97       AFG  Afghanistan  2021  female     40_49      5.392730
# 98       AFG  Afghanistan  2021    male     40_49      9.694572
# 99       AGO       Angola  2000  female       ALL      3.605200
# 100      AGO       Angola  2000    male       ALL     14.822332
#
# [101 rows x 6 columns]
